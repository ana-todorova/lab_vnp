# %%
import pandas as pd

# %%
df = pd.read_csv("pollution_dataset.csv")

# %%
df.head()
# Out:
#    Temperature  Humidity  PM2.5  PM10   NO2   SO2    CO  \
# 0         29.8      59.1    5.2  17.9  18.9   9.2  1.72
# 1         28.3      75.6    2.3  12.2  30.8   9.7  1.64
# 2         23.1      74.7   26.7  33.8  24.4  12.6  1.63
# 3         27.1      39.1    6.1   6.3  13.5   5.3  1.15
# 4         26.5      70.7    6.9  16.0  21.9   5.6  1.01
#
#    Proximity_to_Industrial_Areas  Population_Density Air Quality
# 0                            6.3                 319    Moderate
# 1                            6.0                 611    Moderate
# 2                            5.2                 619    Moderate
# 3                           11.1                 551        Good
# 4                           12.7                 303        Good

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %%
encoder = LabelEncoder()
df['Air Quality'] = encoder.fit_transform(df['Air Quality'])

# %%
X = df.drop(columns=['Air Quality'])
y = df['Air Quality']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4000 entries, 2913 to 2732
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Temperature                    4000 non-null   float64
#  1   Humidity                       4000 non-null   float64
#  2   PM2.5                          4000 non-null   float64
#  3   PM10                           4000 non-null   float64
#  4   NO2                            4000 non-null   float64
#  5   SO2                            4000 non-null   float64
#  6   CO                             4000 non-null   float64
#  7   Proximity_to_Industrial_Areas  4000 non-null   float64
#  8   Population_Density             4000 non-null   int64
# dtypes: float64(8), int64(1)
# memory usage: 312.5 KB

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report

# %%
def create_model(layer_config, activation, input_dim, optimizer):
    model = Sequential()
    for units in layer_config:
        model.add(Dense(units, activation=activation, input_dim=input_dim))
        input_dim = 9
    model.add(Dense(4, activation='softmax'))
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
configs = [
    ([64, 32], 'relu'),
    ([128, 64, 32], 'tanh'),
    ([256, 128, 64, 32], 'sigmoid')
]

# %%
for i, (layer_config, activation) in enumerate(configs, 1):
    optimizer = Adam(learning_rate=0.001)
    model = create_model(layer_config, activation, input_dim=X_train.shape[1], optimizer=optimizer)
    
    history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_split=0.2)

    loss, accuracy = model.evaluate(X_test, y_test)
    print(f"Model {i} - Loss: {loss:.4f}, Accuracy: {accuracy:.4f}")

    y_pred = model.predict(X_test)
    y_pred_classes = y_pred.argmax(axis=1)

    print(f"Classification Report for Model {i}:\n")
    print(classification_report(y_test, y_pred_classes))
# Out:
# C:\Users\Ana\anaconda3\envs\myenv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.3138 - loss: 15.3758 - val_accuracy: 0.4963 - val_loss: 1.2901
# Epoch 2/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4952 - loss: 1.3270 - val_accuracy: 0.5300 - val_loss: 1.7601
# Epoch 3/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5591 - loss: 1.2356 - val_accuracy: 0.6587 - val_loss: 1.1893
# Epoch 4/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6041 - loss: 1.0848 - val_accuracy: 0.6712 - val_loss: 0.9721
# Epoch 5/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6681 - loss: 0.8297 - val_accuracy: 0.6250 - val_loss: 0.9011
# Epoch 6/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6623 - loss: 0.9206 - val_accuracy: 0.6538 - val_loss: 0.9125
# Epoch 7/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6596 - loss: 1.1496 - val_accuracy: 0.6938 - val_loss: 0.6791
# Epoch 8/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6864 - loss: 0.7585 - val_accuracy: 0.6913 - val_loss: 0.8276
# Epoch 9/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.
30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7578 - loss: 0.5834 - val_accuracy: 0.8288 - val_loss: 0.4962
# Epoch 5/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7910 - loss: 0.5007 - val_accuracy: 0.7600 - val_loss: 0.5342
# Epoch 6/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7805 - loss: 0.4987 - val_accuracy: 0.8138 - val_loss: 0.4625
# Epoch 7/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8105 - loss: 0.4372 - val_accuracy: 0.8213 - val_loss: 0.4346
# Epoch 8/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7964 - loss: 0.4421 - val_accuracy: 0.8438 - val_loss: 0.4289
# Epoch 9/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8229 - loss: 0.4174 - val_accuracy: 0.8263 - val_loss: 0.4106
# Epoch 10/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8093 - loss: 0.4261 - val_accuracy: 0.8487 - val_loss: 0.4009
# Epoch 11/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8044 - loss: 0.4581 - val_accuracy: 0.8338 - val_loss: 0.4287
# Epoch 12/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8251 - loss: 0.4266 - val_accuracy: 0.8138 - val_loss: 0.4511
# Epoch 13/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8250 - loss: 0.4248 - val_accuracy: 0.8500 - val_loss: 0.4025
# Epoch 14/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8435 - loss: 0.3880 - val_accuracy: 0.8300 - val_loss: 0.4215
# Epoch 15/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8379 - loss: 0.3926 - val_accuracy: 0.8138 - val_loss: 0.4271
# Epoch 16/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8423 - loss: 0.3803 - val_accuracy: 0.7550 - val_loss: 0.4767
# Epoch 17/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8301 - loss: 0.4165 - val_accuracy: 0.8637 - val_loss: 0.3700
# Epoch 18/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8647 - loss: 0.3630 - val_accuracy: 0.8363 - val_loss: 0.3810
# Epoch 19/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8463 - loss: 0.3794 - val_accuracy: 0.8188 - val_loss: 0.4181
# Epoch 20/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8332 - loss: 0.3865 - val_accuracy: 0.8537 - val_loss: 0.3781
# Epoch 21/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8512 - loss: 0.3733 - val_accuracy: 0.8587 - val_loss: 0.3647
# Epoch 22/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8650 - loss: 0.3491 - val_accuracy: 0.8612 - val_loss: 0.3731
# Epoch 23/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8493 - loss: 0.3683 - val_accuracy: 0.8675 - val_loss: 0.3583
# Epoch 24/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8524 - loss: 0.3791 - val_accuracy: 0.8650 - val_loss: 0.3561
# Epoch 25/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8677 - loss: 0.3672 - val_accuracy: 0.8425 - val_loss: 0.3948
# Epoch 26/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8485 - loss: 0.3717 - val_accuracy: 0.8100 - val_loss: 0.4580
# Epoch 27/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8344 - loss: 0.4027 - val_accuracy: 0.8650 - val_loss: 0.3604
# Epoch 28/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8651 - loss: 0.3462 - val_accuracy: 0.8625 - val_loss: 0.3499
# Epoch 29/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8676 - loss: 0.3413 - val_accuracy: 0.8637 - val_loss: 0.3670
# Epoch 30/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8782 - loss: 0.3150 - val_accuracy: 0.7937 - val_loss: 0.4841
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8145 - loss: 0.4175
# Model 3 - Loss: 0.4347, Accuracy: 0.7980
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Classification Report for Model 3:
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       411
#            1       0.00      0.00      0.00       106
#            2       0.76      0.96      0.85       295
#            3       0.51      0.56      0.53       188
#
#     accuracy                           0.80      1000
#    macro avg       0.56      0.63      0.59      1000
# weighted avg       0.72      0.80      0.75      1000
# C:\Users\Ana\anaconda3\envs\myenv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Ana\anaconda3\envs\myenv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Ana\anaconda3\envs\myenv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
